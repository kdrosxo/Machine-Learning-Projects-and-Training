# %% [markdown]
# ### PCA or principal component analysis is a dimensionality reduction technique that can help us reduce dimensions of dataset that we use in machine learning for training

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('C:/Users/Drosxo/heart.csv')

# %%
df.shape
# Out:
# (918, 12)

# %%
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
df.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %%
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
df['zscore1'] = ( df.Cholesterol - df.Cholesterol.mean() ) / df.Cholesterol.std()
df_no_outliers = df[(df.zscore1>-3) & (df.zscore1<3)] 
df[df['zscore1']< 3]
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease   zscore1
# ...

# %%
df_no_outliers.shape
# Out:
# (915, 13)

# %%
df['zscore2'] = ( df.RestingBP - df.RestingBP.mean() ) / df.RestingBP.std()
df_no_outliers = df[(df.zscore2>-3) & (df.zscore2<3)] 
df_no_outliers.shape
# Out:
# (910, 14)

# %%
df['zscore3'] = ( df.Age - df.Age.mean() ) / df.Age.std()

# %%
df_no_outliers= df[(df.zscore3>-3) & (df.zscore3<3)] 
df_no_outliers.shape
# Out:
# (918, 15)

# %%
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease   zscore1   zscore2   zscore3
# 0              N      0.0       Up             0  0.824621  0.410685 -1.432359
# 1              N      1.0     Flat             1 -0.171867  1.490940 -0.478223
# 2              N      0.0       Up             0  0.769768 -0.129442 -1.750404
# 3              Y      1.5     Flat             1  0.138964  0.302660 -0.584238
# 4              N      0.0       Up             0 -0.034736  0.950812  0.051853

# %%
df_no_outliers[df_no_outliers['zscore3']<-3]
# Out:
# Empty DataFrame
# Columns: [Age, Sex, ChestPainType, RestingBP, Cholesterol, FastingBS, RestingECG, MaxHR, ExerciseAngina, Oldpeak, ST_Slope, HeartDisease, zscore1, zscore2, zscore3]
# Index: []

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le_sex = LabelEncoder()
df_no_outliers['Sex_n'] = le_sex.fit_transform(df_no_outliers['Sex'])

# %%
df_no_outliers.drop(['Sex'],axis='columns')
# Out:
#      Age ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0     40           ATA        140          289          0     Normal    172
# 1     49           NAP        160          180          0     Normal    156
# 2     37           ATA        130          283          0         ST     98
# 3     48           ASY        138          214          0     Normal    108
# 4     54           NAP        150          195          0     Normal    122
# ..   ...           ...        ...          ...        ...        ...    ...
# 913   45            TA        110          264          0     Normal    132
# 914   68           ASY        144          193          1     Normal    141
# 915   57           ASY        130          131          0     Normal    115
# 916   57           ATA        130          236          0        LVH    174
# 917   38           NAP        138          175          0     Normal    173
#
# ...

# %%
le_slope = LabelEncoder()
df_no_outliers['ST_Slope_n'] = le_slope.fit_transform(df_no_outliers['ST_Slope'])

# %%
le_ExerciseAngina = LabelEncoder()
df_no_outliers['ExerciseAngina_n'] = le_ExerciseAngina.fit_transform(df_no_outliers['ExerciseAngina'])

# %%
df_no_outliers['RestingECG_n'] = LabelEncoder().fit_transform(df_no_outliers['RestingECG'])

# %%
df_no_outliers['ChestPainType'] = LabelEncoder().fit_transform(df_no_outliers['ChestPainType'])

# %%
df_no_outliers.drop(['Sex','ChestPainType','RestingECG','ExerciseAngina','ST_Slope'],axis='columns')
# Out:
#      Age  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease  \
# 0     40        140          289          0    172      0.0             0
# 1     49        160          180          0    156      1.0             1
# 2     37        130          283          0     98      0.0             0
# 3     48        138          214          0    108      1.5             1
# 4     54        150          195          0    122      0.0             0
# ..   ...        ...          ...        ...    ...      ...           ...
# 913   45        110          264          0    132      1.2             1
# 914   68        144          193          1    141      3.4             1
# 915   57        130          131          0    115      1.2             1
# 916   57        130          236          0    174      0.0             1
# 917   38        138          175          0    173      0.0             0
#
#       zscore1   zscore2   zscore3  Sex_n  ST_Slope_n  ExerciseAngina_n  \
# ...

# %%
df_no_outliers.head()
# Out:
#    Age Sex  ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0   40   M              1        140          289          0     Normal
# 1   49   F              2        160          180          0     Normal
# 2   37   M              1        130          283          0         ST
# 3   48   F              0        138          214          0     Normal
# 4   54   M              2        150          195          0     Normal
#
#    MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease   zscore1   zscore2  \
# 0    172              N      0.0       Up             0  0.824621  0.410685
# 1    156              N      1.0     Flat             1 -0.171867  1.490940
# 2     98              N      0.0       Up             0  0.769768 -0.129442
# 3    108              Y      1.5     Flat             1  0.138964  0.302660
# 4    122              N      0.0       Up             0 -0.034736  0.950812
#
#     zscore3  Sex_n  ST_Slope_n  ExerciseAngina_n  RestingECG_n
# ...

# %%
data = df_no_outliers.drop(['Sex','ChestPainType','RestingECG','ExerciseAngina','ST_Slope','zscore1','zscore2'],axis='columns')

# %%
data.head()
# Out:
#    Age  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease  \
# 0   40        140          289          0    172      0.0             0
# 1   49        160          180          0    156      1.0             1
# 2   37        130          283          0     98      0.0             0
# 3   48        138          214          0    108      1.5             1
# 4   54        150          195          0    122      0.0             0
#
#     zscore3  Sex_n  ST_Slope_n  ExerciseAngina_n  RestingECG_n
# 0 -1.432359      1           2                 0             1
# 1 -0.478223      0           1                 0             1
# 2 -1.750404      1           2                 0             2
# 3 -0.584238      0           1                 1             1
# 4  0.051853      1           2                 0             1

# %%
X = data[['Age','RestingBP','Cholesterol','FastingBS','MaxHR','Oldpeak','Sex_n','ST_Slope_n','ExerciseAngina_n','RestingECG_n']].values

# %%
target = df.HeartDisease
df = df.drop(columns = 'HeartDisease')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-85-0c481f6ff7f2> in <module>
# ----> 1 target = df.HeartDisease
#       2 df = df.drop(columns = 'HeartDisease')
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'HeartDisease'

# %%
target.shape
# Out:
# (918,)

# %%
data.shape
# Out:
# (918, 12)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_scaled
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-83-367df9d76a23> in <module>
#       2
#       3 scaler = StandardScaler()
# ----> 4 X_scaled = scaler.fit_transform(X)
#       5 X_scaled
#
# NameError: name 'X' is not defined

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_scaled, target, test_size=0.2, random_state=30)

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier

# %%
model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto'),
        'params' : {
            'C': [1,10,20],
            'kernel': ['rbf','linear','sigmoid']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'n_estimators': [1,5,10,20,40,50,75,100,200,250,400,500]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'C': [1,5,10]
        }
    },
    'naive_bayes_gaussian': {
        'model': GaussianNB(),
        'params': {}
   
    },
    'decision_tree': {
        'model': DecisionTreeClassifier(),
        'params': {
            'criterion': ['gini','entropy'],
            
        }
    }     
}

# %%
from sklearn.model_selection import GridSearchCV
scores = []

for model_name, mp in model_params.items():
    clf =  GridSearchCV(mp['model'], mp['params'], cv=5, return_train_score=False)
    clf.fit(X_scaled, target)
    scores.append({
        'model': model_name,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    
db = pd.DataFrame(scores,columns=['model','best_score','best_params'])
db

# %%
from sklearn.decomposition import PCA

pca = PCA(0.95)
X_pca = pca.fit_transform(X)
X_pca

# %%
X_train_pca, X_test_pca, y_train, y_test = train_test_split(X_pca, target, test_size=0.2, random_state=30)

# %%
model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto'),
        'params' : {
            'C': [1,10,20],
            'kernel': ['rbf','linear','sigmoid']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'n_estimators': [1,5,10,20,40,50,75,100,200,250,400,500]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'C': [1,5,10]
        }
    },
    'naive_bayes_gaussian': {
        'model': GaussianNB(),
        'params': {}
   
    },
    'decision_tree': {
        'model': DecisionTreeClassifier(),
        'params': {
            'criterion': ['gini','entropy'],
            
        }
    }     
}

# %%
from sklearn.model_selection import GridSearchCV
scores = []

for model_name, mp in model_params.items():
    clf =  GridSearchCV(mp['model'], mp['params'], cv=5, return_train_score=False)
    clf.fit(X_pca, target)
    scores.append({
        'model': model_name,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    
db = pd.DataFrame(scores,columns=['model','best_score','best_params'])
db
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-79-4aefdd8820e2> in <module>
#       2 scores = []
#       3
# ----> 4 for model_name, mp in model_params.items():
#       5     clf =  GridSearchCV(mp['model'], mp['params'], cv=5, return_train_score=False)
#       6     clf.fit(X_pca, target)
#
# NameError: name 'model_params' is not defined

# %%
from sklearn.ensemble import RandomForestClassifier

model_rf = RandomForestClassifier()
model_rf.fit(X_train_pca, y_train)
model_rf.score(X_test_pca, y_test)

# %%
X = data[['Age','RestingBP','Cholesterol','FastingBS','MaxHR','Oldpeak','Sex_n','ST_Slope_n','ExerciseAngina_n','RestingECG_n']].values

# %%
Y = target.values

# %%
Y.shape

# %%
X

# %%
from sklearn.preprocessing import OneHotEncoder as ohe
from sklearn.compose import ColumnTransformer

ct = ColumnTransformer([('FastingBS','Sex_n','ST_Slope_n','ExerciseAngina_n','RestingECG_n', OneHotEncoder(), [3,6,7,8,9])], remainder = 'passthrough')

# %%
ohe.fit_transform(X).toarray()

# %%
from sklearn.base import

# %%
X_train_pca, X_test_pca, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=30)
